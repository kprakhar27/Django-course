# %% [markdown]
# # KNN Implementation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
headernames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']
dataset = pd.read_csv(path, names = headernames)
dataset.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
X = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, 4].values

print(X.shape)
print(Y.shape)
# Out:
# (150, 4)
# (150,)

# %%
sns.FacetGrid(dataset, hue ="Class",
              height = 6).map(plt.scatter,
                              'sepal-length',
                              'petal-length').add_legend()
plt.show()

# %%
query_X = np.array([6.5,5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-9e8ce036229e> in <module>
#       1 query_X = np.array([6.5,5])
#       2 sns.FacetGrid(dataset, hue ="Class",height = 6).map(plt.scatter,'sepal-length','petal-length').add_legend()
# ----> 3 sns.FacetGrid(dataset, height = 6).map(plt.scatter,query_X[0],query_X[1]).add_legend()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     671
#     672             # Get the actual data we are going to plot with
# --> 673             plot_data = data_ijk[list(args)]
#     674             if self._dropna:
#     675                 plot_data = plot_data.dropna()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Float64Index([6.5, 5.0], dtype='float64')] are in the [columns]"
